# %% [markdown]
# <a href="https://colab.research.google.com/github/manokarthickgit/it-cert-automation-practice/blob/master/git_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Check if jupiter notebook can be run from terminal?
